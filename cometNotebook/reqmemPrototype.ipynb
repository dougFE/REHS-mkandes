# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from time import time
import os
import dask.dataframe as dd
from random import randint
import numpy as np
from dask.array import from_array as fa

sourceFile = '5000mb.csv'  # Source of sacct data if using offline mode.

from dask_jobqueue import SLURMCluster
from dask.distributed import Client

cluster = SLURMCluster() #add arguments if want a cluster outside of the set up defult
cluster = SLURMCluster(cores=24, processes=6, walltime="1:00:00", queue="compute", memory= "120GB")
# Out:
# /home/caolinnh/miniconda3/lib/python3.7/site-packages/distributed/node.py:155: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 38967 instead
#   http_address["port"], self.http_server.port

# %%
cluster.scale(jobs=2)

# %%
client = Client(cluster)
client
# Out:
# <Client: 'tcp://10.22.255.53:46837' processes=0 threads=0, memory=0 B>

# %%
sourceFile = 'benchHome/_1week.csv'
df = dd.read_csv(sourceFile, dtype = 'object', low_memory=False, error_bad_lines=False)
#df = dd.read_parquet(sourceFile)  # For if you're smart and use parquet files instead of csvs

# %%
pd.set_option('display.max.columns', None)
pd.set_option('display.width', 150)
print(df.shape,'\n\n')
print(df.head(),'\n\n')
df.describe()
# Out:
# (Delayed('int-1b0a231d-f8aa-4c37-9927-7ae1a9a3250e'), 76)
#
#
#   Unnamed: 0  JobIDRaw   step           JobID  UID  GID AssocID Cluster JobName User Group Account Reservation ReservationId Partition  QOS QOSRAW  \
# 0          0  33558654  batch  33558654.batch  NaN  NaN    7461   comet   batch  NaN   NaN  uic342         NaN           NaN       NaN  NaN    NaN
# 1          1  33558658  batch  33558658.batch  NaN  NaN    7461   comet   batch  NaN   NaN  uic342         NaN           NaN       NaN  NaN    NaN
# 2          2  33558659  batch  33558659.batch  NaN  NaN    7461   comet   batch  NaN   NaN  uic342         NaN           NaN       NaN  NaN    NaN
# 3          3  33558661  batch  33558661.batch  NaN  NaN    7461   comet   batch  NaN   NaN  uic342         NaN           NaN       NaN  NaN    NaN
# 4          4  33558686  batch  33558686.batch  NaN  NaN    7461   comet   batch  NaN   NaN  uic342         NaN           NaN       NaN  NaN    NaN
#
#   NNODES NTASKS NCPUS AllocCPUS ReqCPUS ReqCPUFreq ReqMem ReqGRES AllocGRES Timelimit Priority   State ExitCode DerivedExitCode  \
# 0      1      1    24        24      24          0  120Gn     NaN       NaN       NaN      NaN  FAILED      6:0             NaN
# 1      1      1    24        24      24          0  120Gn     NaN       NaN       NaN      NaN  FAILED      6:0             NaN
# 2      1      1    24        24      24          0  120Gn     NaN       NaN       NaN      NaN  FAILED      6:0             NaN
# 3      1      1    24        24      24          0  120Gn     NaN       NaN       NaN      NaN  FAILED      6:0             NaN
# 4      1      1    24        24      24          0  120Gn     NaN       NaN       NaN      NaN  FAILED      6:0             NaN
#
#                 Submit             Eligible                Start                  End Time   Elapsed Reserved Suspended       AveCPU       MinCPU  \
# 0  2020-06-01T00:00:00  2020-06-01T00:00:00  2020-06-01T00:00:00  2020-06-01T11:20:30  NaN  11:20:30  INVALID  00:00:00  20-10:21:56  20-10:21:56
# 1  2020-06-02T13:43:13  2020-06-02T13:43:13  2020-06-02T13:43:13  2020-06-03T10:11:05  NaN  20:27:52  INVALID  00:00:00  19-14:12:13  19-14:12:13
# 2  2020-06-03T22:54:56  2020-06-03T22:54:56  2020-06-03T22:54:56  2020-06-04T19:51:10  NaN  20:56:14  INVALID  00:00:00  20-01:07:47  20-01:07:47
# 3  2020-06-05T05:05:23  2020-06-05T05:05:23  2020-06-05T05:05:23  2020-06-06T01:55:44  NaN  20:50:21  INVALID  00:00:00  19-22:46:12  19-22:46:12
# 4  2020-06-01T00:00:00  2020-06-01T00:00:00  2020-06-01T00:00:00  2020-06-01T11:29:51  NaN  11:29:51  INVALID  00:00:00  20-14:06:18  20-14:06:18
#
#     MinCPUNode MinCPUTask  ResvCPU ResvCPURaw     TotalCPU  SystemCPU      UserCPU      CPUTime CPUTimeRaw AveCPUFreq AveDiskRead MaxDiskRead  \
# 0  comet-26-15        0.0  INVALID        NaN  20-10:26:09  31:49.118  20-09:54:19  11-08:12:00     979920      1.31M         11M         11M
# 1  comet-19-56        0.0  INVALID        NaN  19-14:19:11  34:58.294  19-13:44:12  20-11:08:48    1768128       311K         11M         11M
# 2  comet-22-28        0.0  INVALID        NaN  20-01:11:29  36:55.076  20-00:34:34  20-22:29:36    1808976       683K         11M         11M
# 3  comet-21-05        0.0  INVALID        NaN  19-22:52:25  41:28.179  19-22:10:57  20-20:08:24    1800504       321K         11M         11M
# 4  comet-26-16        0.0  INVALID        NaN  20-14:07:06  31:21.331  20-13:35:45  11-11:56:24     993384      1.71M         12M         12M
#
#   MaxDiskReadNode MaxDiskReadTask AveDiskWrite MaxDiskWrite MaxDiskWriteNode MaxDiskWriteTask AvePages MaxPages MaxPagesNode MaxPagesTask   AveRss  \
# 0     comet-26-15             0.0        1418M        1418M      comet-26-15              0.0      72K      72K  comet-26-15          0.0  109972K
# 1     comet-19-56             0.0        1418M        1418M      comet-19-56              0.0      72K      72K  comet-19-56          0.0  109048K
# 2     comet-22-28             0.0        1418M        1418M      comet-22-28              0.0      61K      61K  comet-22-28          0.0  110024K
# 3     comet-21-05             0.0        1418M        1418M      comet-21-05              0.0      72K      72K  comet-21-05          0.0  109504K
# 4     comet-26-16             0.0        1418M        1418M      comet-26-16              0.0      72K      72K  comet-26-16          0.0  108704K
#
#     MaxRSS   MaxRSSNode MaxRSSTask AveVMSize MaxVMSize MaxVMSizeNode MaxVMSizeTask ConsumedEnergy ConsumedEnergyRaw   Layout Comment     NodeList
# 0  109972K  comet-26-15        0.0  1758336K  1758336K   comet-26-15           0.0            0.0               0.0  Unknown     NaN  comet-26-15
# 1  109048K  comet-19-56        0.0  1757944K  1757944K   comet-19-56           0.0            0.0               0.0  Unknown     NaN  comet-19-56
# 2  110024K  comet-22-28        0.0  1758280K  1758280K   comet-22-28           0.0            0.0               0.0  Unknown     NaN  comet-22-28
# 3  109504K  comet-21-05        0.0  1758228K  1758228K   comet-21-05           0.0            0.0               0.0  Unknown     NaN  comet-21-05
# 4  108704K  comet-26-16        0.0  1754848K  1754848K   comet-26-16           0.0            0.0               0.0  Unknown     NaN  comet-26-16
# Dask DataFrame Structure:
#               Unnamed: 0 JobIDRaw    step   JobID     UID     GID AssocID Cluster JobName    User   Group Account Reservation ReservationId Partition     QOS  QOSRAW  NNODES  NTASKS   NCPUS AllocCPUS ReqCPUS ReqCPUFreq  ReqMem ReqGRES AllocGRES Timelimit Priority   State ExitCode DerivedExitCode  Submit Eligible   Start     End    Time Elapsed Reserved Suspended  AveCPU  MinCPU MinCPUNode MinCPUTask ResvCPU ResvCPURaw TotalCPU SystemCPU UserCPU CPUTime CPUTimeRaw AveCPUFreq AveDiskRead MaxDiskRead MaxDiskReadNode MaxDiskReadTask AveDiskWrite MaxDiskWrite MaxDiskWriteNode MaxDiskWriteTask AvePages MaxPages MaxPagesNode MaxPagesTask  AveRss  MaxRSS MaxRSSNode MaxRSSTask AveVMSize MaxVMSize MaxVMSizeNode MaxVMSizeTask ConsumedEnergy ConsumedEnergyRaw  Layout Comment NodeList
# npartitions=1
#                   object   object  object  object  object  object  object  object  object  object  object  object      object        object    object  object  object  object  object  object    object  object     object  object  object    object    object   object  object   object          object  object   object  object  object  object  object   object    object  object  object     object     object  object     object   object    object  object  object     object     object      object      object          object          object       object       object           object           object   object   object       object       object  object  object     object     object    object    object        object        object         object            object  object  object   object
#                      ...      ...     ...     ...     ...     ...     ...     ...     ...     ...     ...     ...         ...           ...       ...     ...     ...     ...     ...     ...       ...     ...        ...     ...     ...       ...       ...      ...     ...      ...             ...     ...      ...     ...     ...     ...     ...      ...       ...     ...     ...        ...        ...     ...        ...      ...       ...     ...     ...        ...        ...         ...         ...             ...             ...          ...          ...              ...              ...      ...      ...          ...          ...     ...     ...        ...        ...       ...       ...           ...           ...            ...               ...     ...     ...      ...
# Dask Name: describe, 1067 tasks

# %%
# Get info on single account usage
userDF = df.loc[df['Account'] == 'csd450']
print(userDF[['Account', 'JobIDRaw', 'JobName', 'State', 'ExitCode', 'Start', 'End']])
# Out:
# Dask DataFrame Structure:
#               Account JobIDRaw JobName   State ExitCode   Start     End
# npartitions=2
#                object   object  object  object   object  object  object
#                   ...      ...     ...     ...      ...     ...     ...
#                   ...      ...     ...     ...      ...     ...     ...
# Dask Name: getitem, 10 tasks

# %%
# Get info on multiple account usage

accountList = ['mit178', 'dku133', 'cla176']
#df['NNODES']= df['NNODES'].astype(float)
#queryDF = df.loc[df['NNODES'] <= 1 ]
queryDF = df.loc[df['Account'].isin(accountList )]
#print(userDF[['Account', 'JobIDRaw', 'JobName', 'State', 'ExitCode', 'Start']].compute())

# %%
newquery = queryDF.compute().sort_values('Start', ascending=False)

# %%
for orig in queryDF['MaxRSS']:
    if (type(orig) != int) and (type(orig) != float):
        if (orig[-1] == "K"):
            num = float(orig[0 : -1])
            queryDF["MaxRSS"] = queryDF["MaxRSS"].replace(orig, num)
        elif (orig[-1] == "M"):
            num = float(orig[0 : -1]) * 1024
            queryDF["MaxRSS"] = queryDF["MaxRSS"].replace(orig, num)
        elif (orig[-1] == "G"):
            num = float(orig[0 : -1]) * 1024 * 1024
            queryDF["MaxRSS"] = queryDF["MaxRSS"].replace(orig, num)
        elif (orig == ""):
            queryDF["MaxRSS"] = queryDF["MaxRSS"].replace(orig, 0.0)

# %%
for ori, core in zip(queryDF['ReqMem'], queryDF["NCPUS"]):
    if (type(ori) != int) and (type(ori) != float):
        if (ori[-1] == "n"):
            if (ori[-2] == "K"):
                num = float(ori[0 : -2])
                queryDF["ReqMem"] = queryDF["ReqMem"].replace(ori, num)
            elif (ori[-2] == "M"):
                num = float(orig[0 : -2]) * 1024
                queryDF["ReqMem"] = queryDF["ReqMem"].replace(ori, num)
            elif (ori[-2] == "G"):
                num = float(orig[0 : -2]) * 1024 * 1024
                queryDF["ReqMem"] = queryDF["ReqMem"].replace(ori, num)
        elif (ori == ""):
                queryDF["ReqMem"] = queryDF["ReqMem"].replace(ori, 0.0)
        elif (ori[-1] == "c"):
            if (ori[-2] == "K"):
                num = float(ori[0 : -2]) * float(core)
                queryDF["ReqMem"] = queryDF["ReqMem"].replace(ori, num)
            elif (ori[-2] == "M"):
                num = float(orig[0 : -2]) * 1024 * float(core)
                queryDF["ReqMem"] = queryDF["ReqMem"].replace(ori, num)
            elif (ori[-2] == "G"):
                num = float(orig[0 : -2]) * 1024 * 1024 * float(core)
                queryDF["ReqMem"] = queryDF["ReqMem"].replace(ori, num)

# %%
pd.set_option("display.max.rows", 100)
queryDF['MaxRSS']=queryDF['MaxRSS'].astype(float)
queryDF['ReqMem']=queryDF['ReqMem'].astype(float)
queryDF.dtypes
# Out:
# Unnamed: 0            object
# JobIDRaw              object
# step                  object
# JobID                 object
# UID                   object
# GID                   object
# AssocID               object
# Cluster               object
# JobName               object
# User                  object
# Group                 object
# Account               object
# Reservation           object
# ReservationId         object
# Partition             object
# QOS                   object
# QOSRAW                object
# NNODES                object
# NTASKS                object
# NCPUS                 object
# AllocCPUS             object
# ReqCPUS               object
# ReqCPUFreq            object
# ReqMem               float64
# ReqGRES               object
# AllocGRES             object
# Timelimit             object
# Priority              object
# State                 object
# ExitCode              object
# DerivedExitCode       object
# Submit                object
# Eligible              object
# Start                 object
# End                   object
# Time                  object
# Elapsed               object
# Reserved              object
# Suspended             object
# AveCPU                object
# MinCPU                object
# MinCPUNode            object
# MinCPUTask            object
# ResvCPU               object
# ResvCPURaw            object
# TotalCPU              object
# SystemCPU             object
# UserCPU               object
# CPUTime               object
# CPUTimeRaw            object
# AveCPUFreq            object
# AveDiskRead           object
# MaxDiskRead           object
# MaxDiskReadNode       object
# MaxDiskReadTask       object
# AveDiskWrite          object
# MaxDiskWrite          object
# MaxDiskWriteNode      object
# MaxDiskWriteTask      object
# AvePages              object
# MaxPages              object
# MaxPagesNode          object
# MaxPagesTask          object
# AveRss                object
# MaxRSS               float64
# MaxRSSNode            object
# MaxRSSTask            object
# AveVMSize             object
# MaxVMSize             object
# MaxVMSizeNode         object
# MaxVMSizeTask         object
# ConsumedEnergy        object
# ConsumedEnergyRaw     object
# Layout                object
# Comment               object
# NodeList              object
# dtype: object

# %%
queryDF['diff'] = queryDF['ReqMem'] - queryDF['MaxRSS']

# %%
queryDF['diff']=queryDF['diff'].astype(float)
#len(df.query('diff < 0  '))
queryDF["diff"]
# Out:
# Dask Series Structure:
# npartitions=2
#     float64
#         ...
#         ...
# Name: diff, dtype: float64
# Dask Name: getitem, 1711 tasks

# %%
len(queryDF.query('diff  10000000000'))
# Out:
# 0

# %%
def maxRSS_convert(orig):
    orig = str(orig)
    if (orig[-1] == "K"):
        num = orig[0 : -1]
        return int(num)
    elif (orig[-1] == "M"):
        num = int(orig[0 : -1])
        return int(num*1024)
    elif (orig[-1] == "G"):
        num = int(orig[0 : -1])
        return int(num*1024*1024)
    elif (orig == ""):
        return 0

# %%
#len(queryDF.query('Max > 5000000 '))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-56-07711a479b1b> in <module>
# ----> 1 len(queryDF.query('ReqMem > 5000000 '))
#
# ~/miniconda3/lib/python3.7/site-packages/dask/dataframe/core.py in __len__(self)
#    3612             return super().__len__()
#    3613         else:
# -> 3614             return len(s)
#    3615
#    3616     def __contains__(self, key):
#
# ~/miniconda3/lib/python3.7/site-packages/dask/dataframe/core.py in __len__(self)
#     542     def __len__(self):
#     543         return self.reduction(
# --> 544             len, np.sum, token="len", meta=int, split_every=False
#     545         ).compute()
#     546
#
# ~/miniconda3/lib/python3.7/site-packages/dask/base.py in compute(self, **kwargs)
#     277         dask.base.compute
#     278         """
# --> 279         (result,) = compute(self, traverse=False, **kwargs)
#     280         return result
#     281
#
# ~/miniconda3/lib/python3.7/site-packages/dask/base.py in compute(*args, **kwargs)
#     565         postcomputes.append(x.__dask_postcompute__())
#     566
# --> 567     results = schedule(dsk, keys, **kwargs)
#     568     return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#     569
#
# ~/miniconda3/lib/python3.7/site-packages/distributed/client.py in get(self, dsk, keys, restrictions, loose_restrictions, resources, sync, asynchronous, direct, retries, priority, fifo_timeout, actors, **kwargs)
#    2674                     should_rejoin = False
#    2675             try:
# -> 2676                 results = self.gather(packed, asynchronous=asynchronous, direct=direct)
#    2677             finally:
#    2678                 for f in futures.values():
#
# ~/miniconda3/lib/python3.7/site-packages/distributed/client.py in gather(self, futures, errors, direct, asynchronous)
#    1989                 direct=direct,
#    1990                 local_worker=local_worker,
# -> 1991                 asynchronous=asynchronous,
#    1992             )
#    1993
#
# ~/miniconda3/lib/python3.7/site-packages/distributed/client.py in sync(self, func, asynchronous, callback_timeout, *args, **kwargs)
#     830         else:
#     831             return sync(
# --> 832                 self.loop, func, *args, callback_timeout=callback_timeout, **kwargs
#     833             )
#     834
#
# ~/miniconda3/lib/python3.7/site-packages/distributed/utils.py in sync(loop, func, callback_timeout, *args, **kwargs)
#     338     if error[0]:
#     339         typ, exc, tb = error[0]
# --> 340         raise exc.with_traceback(tb)
#     341     else:
#     342         return result[0]
#
# ~/miniconda3/lib/python3.7/site-packages/distributed/utils.py in f()
#     322             if callback_timeout is not None:
#     323                 future = asyncio.wait_for(future, callback_timeout)
# --> 324             result[0] = yield future
#     325         except Exception as exc:
#     326             error[0] = sys.exc_info()
#
# ~/miniconda3/lib/python3.7/site-packages/tornado/gen.py in run(self)
#     760
#     761                     try:
# --> 762                         value = future.result()
#     763                     except Exception:
#     764                         exc_info = sys.exc_info()
#
# ~/miniconda3/lib/python3.7/site-packages/distributed/client.py in _gather(self, futures, errors, direct, local_worker)
#    1848                             exc = CancelledError(key)
#    1849                         else:
# -> 1850                             raise exception.with_traceback(traceback)
#    1851                         raise exc
#    1852                     if errors == "skip":
#
# ~/miniconda3/lib/python3.7/site-packages/dask/optimization.py in __call__()
#     961         if not len(args) == len(self.inkeys):
#     962             raise ValueError("Expected %d args, got %d" % (len(self.inkeys), len(args)))
# --> 963         return core.get(self.dsk, self.outkey, dict(zip(self.inkeys, args)))
#     964
#     965     def __reduce__(self):
#
# ~/miniconda3/lib/python3.7/site-packages/dask/core.py in get()
#     149     for key in toposort(dsk):
#     150         task = dsk[key]
# --> 151         result = _execute_task(task, cache)
#     152         cache[key] = result
#     153     result = _execute_task(out, cache)
#
# ~/miniconda3/lib/python3.7/site-packages/dask/core.py in _execute_task()
#     119         # temporaries by their reference count and can execute certain
#     120         # operations in-place.
# --> 121         return func(*(_execute_task(a, cache) for a in args))
#     122     elif not ishashable(arg):
#     123         return arg
#
# ~/miniconda3/lib/python3.7/site-packages/dask/core.py in <genexpr>()
#     119         # temporaries by their reference count and can execute certain
#     120         # operations in-place.
# --> 121         return func(*(_execute_task(a, cache) for a in args))
#     122     elif not ishashable(arg):
#     123         return arg
#
# ~/miniconda3/lib/python3.7/site-packages/dask/core.py in _execute_task()
#     119         # temporaries by their reference count and can execute certain
#     120         # operations in-place.
# --> 121         return func(*(_execute_task(a, cache) for a in args))
#     122     elif not ishashable(arg):
#     123         return arg
#
# ~/miniconda3/lib/python3.7/site-packages/dask/utils.py in apply()
#      28 def apply(func, args, kwargs=None):
#      29     if kwargs:
# ---> 30         return func(*args, **kwargs)
#      31     else:
#      32         return func(*args)
#
# ~/miniconda3/lib/python3.7/site-packages/dask/utils.py in __call__()
#     892
#     893     def __call__(self, obj, *args, **kwargs):
# --> 894         return getattr(obj, self.method)(*args, **kwargs)
#     895
#     896     def __reduce__(self):
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/generic.py in astype()
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in astype()
#     580
#     581     def astype(self, dtype, copy: bool = False, errors: str = "raise"):
# --> 582         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     583
#     584     def convert(self, **kwargs):
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in apply()
#     440                 applied = b.apply(f, **kwargs)
#     441             else:
# --> 442                 applied = getattr(b, f)(**kwargs)
#     443             result_blocks = _extend_blocks(applied, result_blocks)
#     444
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/internals/blocks.py in astype()
#     623             vals1d = values.ravel()
#     624             try:
# --> 625                 values = astype_nansafe(vals1d, dtype, copy=True)
#     626             except (ValueError, TypeError):
#     627                 # e.g. astype_nansafe can fail on object-dtype of strings
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/dtypes/cast.py in astype_nansafe()
#     895     if copy or is_object_dtype(arr) or is_object_dtype(dtype):
#     896         # Explicit copy, or required since NumPy can't view from / to object.
# --> 897         return arr.astype(dtype, copy=True)
#     898
#     899     return arr.view(dtype)
#
# ValueError: could not convert string to float: '4Gn'

# %%
maxRSS_convert('5M')
# Out:
# 5120

# %%
accountList = ['mit178', 'dku133', 'cla176']

queryDF = df.loc[df['Account'].isin(accountList)]
#print(userDF[['Account', 'JobIDRaw', 'JobName', 'State', 'ExitCode', 'Start']].compute())

# %%
# Graphing jobs per account
sns.histplot(data=queryDF, x="Account")

# %%
# Graphing node usage 
sns.histplot(data=df.loc[df['NodeList'].isin(['comet-10-48','comet-05-54','comet-15-57'])], x = 'NodeList')

# %%
# Display query dataframe preview
queryDF.head(50)
# Out:
#       Unnamed: 0  JobIDRaw   step           JobID  UID  GID AssocID Cluster JobName User Group Account Reservation ReservationId Partition  QOS  \
# 1908        1908  33783628  batch  33783628.batch  NaN  NaN   15294   comet   batch  NaN   NaN  cla176         NaN           NaN       NaN  NaN
# 3021        3021  33796528  batch  33796528.batch  NaN  NaN   15294   comet   batch  NaN   NaN  cla176         NaN           NaN       NaN  NaN
# 4196        4196  33804402  batch  33804402.batch  NaN  NaN   15294   comet   batch  NaN   NaN  cla176         NaN           NaN       NaN  NaN
# 4197        4197  33804405  batch  33804405.batch  NaN  NaN   15294   comet   batch  NaN   NaN  cla176         NaN           NaN       NaN  NaN
# 4198        4198  33804407  batch  33804407.batch  NaN  NaN   15294   comet   batch  NaN   NaN  cla176         NaN           NaN       NaN  NaN
# 4199        4199  33804408  batch  33804408.batch  NaN  NaN   15294   comet   batch  NaN   NaN  cla176         NaN           NaN       NaN  NaN
# 17683      17683  33812638  batch  33812638.batch  NaN  NaN   16992   comet   batch  NaN   NaN  cla176         NaN           NaN       NaN  NaN
# 30174      30174  33820134  batch  33820134.batch  NaN  NaN   15294   comet   batch  NaN   NaN  cla176         NaN           NaN       NaN  NaN
# 30175      30175  33820135  batch  33820135.batch  NaN  NaN   15294   comet   batch  NaN   NaN  cla176         NaN           NaN       NaN  NaN
# 30177      30177  33820137  batch  33820137.batch  NaN  NaN   15294   comet   batch  NaN   NaN  cla176         NaN           NaN       NaN  NaN
# 31037      31037  33820892  batch  33820892.batch  NaN  NaN   24786   comet   batch  NaN   NaN  mit178         NaN           NaN       NaN  NaN
# 32876      32876  33822121  batch  33822121.batch  NaN  NaN   15294   comet   batch  NaN   NaN  cla176         NaN           NaN       NaN  NaN
# 32877      32877  33822122  batch  33822122.batch  NaN  NaN   15294   comet   batch  NaN   NaN  cla176         NaN           NaN       NaN  NaN
# 32878      32878  33822123  batch  33822123.batch  NaN  NaN   15294   comet   batch  NaN   NaN  cla176         NaN           NaN       NaN  NaN
# 32879      32879  33822124  batch  33822124.batch  NaN  NaN   15294   comet   batch  NaN   NaN  cla176         NaN           NaN       NaN  NaN
# 32880      32880  33822125  batch  33822125.batch  NaN  NaN   15294   comet   batch  NaN   NaN  cla176         NaN           NaN       NaN  NaN
# 32881      32881  33822126  batch  33822126.batch  NaN  NaN   15294   comet   batch  NaN   NaN  cla176         NaN           NaN       NaN  NaN
# 32882      32882  33822127  batch  33822127.batch  NaN  NaN   15294   comet   batch  NaN   NaN  cla176         NaN           NaN       NaN  NaN
# 32883      32883  33822128  batch  33822128.batch  NaN  NaN   15294   comet   batch  NaN   NaN  cla176         NaN           NaN       NaN  NaN
# 32884      32884  33822129  batch  33822129.batch  NaN  NaN   15294   comet   batch  NaN   NaN  cla176         NaN           NaN       NaN  NaN
# 32887      32887  33822132  batch  33822132.batch  NaN  NaN   15294   comet   batch  NaN   NaN  cla176         NaN           NaN       NaN  NaN
# 32888      32888  33822133  batch  33822133.batch  NaN  NaN   15294   comet   batch  NaN   NaN  cla176         NaN           NaN       NaN  NaN
# 32889      32889  33822134  batch  33822134.batch  NaN  NaN   15294   comet   batch  NaN   NaN  cla176         NaN           NaN       NaN  NaN
# 32890      32890  33822135  batch  33822135.batch  NaN  NaN   15294   comet   batch  NaN   NaN  cla176         NaN           NaN       NaN  NaN
# 32891      32891  33822136  batch  33822136.batch  NaN  NaN   15294   comet   batch  NaN   NaN  cla176         NaN           NaN       NaN  NaN
# 32892      32892  33822137  batch  33822137.batch  NaN  NaN   15294   comet   batch  NaN   NaN  cla176         NaN           NaN       NaN  NaN
# 32893      32893  33822138  batch  33822138.batch  NaN  NaN   15294   comet   batch  NaN   NaN  cla176         NaN           NaN       NaN  NaN
# 32894      32894  33822139  batch  33822139.batch  NaN  NaN   15294   comet   batch  NaN   NaN  cla176         NaN           NaN       NaN  NaN
# 32895      32895  33822140  batch  33822140.batch  NaN  NaN   15294   comet   batch  NaN   NaN  cla176         NaN           NaN       NaN  NaN
# 32904      32904  33822148  batch  33822148.batch  NaN  NaN   15294   comet   batch  NaN   NaN  cla176         NaN           NaN       NaN  NaN
# 32905      32905  33822149  batch  33822149.batch  NaN  NaN   15294   comet   batch  NaN   NaN  cla176         NaN           NaN       NaN  NaN
# 32906      32906  33822150  batch  33822150.batch  NaN  NaN   15294   comet   batch  NaN   NaN  cla176         NaN           NaN       NaN  NaN
# 32907      32907  33822151  batch  33822151.batch  NaN  NaN   15294   comet   batch  NaN   NaN  cla176         NaN           NaN       NaN  NaN
# 32908      32908  33822152  batch  33822152.batch  NaN  NaN   15294   comet   batch  NaN   NaN  cla176         NaN           NaN       NaN  NaN
# 32909      32909  33822153  batch  33822153.batch  NaN  NaN   15294   comet   batch  NaN   NaN  cla176         NaN           NaN       NaN  NaN
# 32910      32910  33822154  batch  33822154.batch  NaN  NaN   15294   comet   batch  NaN   NaN  cla176         NaN           NaN       NaN  NaN
# 33071      33071  33822290  batch  33822290.batch  NaN  NaN   15294   comet   batch  NaN   NaN  cla176         NaN           NaN       NaN  NaN
# 34553      34553  33823301  batch  33823301.batch  NaN  NaN   15294   comet   batch  NaN   NaN  cla176         NaN           NaN       NaN  NaN
# 34882      34882  33823555  batch  33823555.batch  NaN  NaN   15294   comet   batch  NaN   NaN  cla176         NaN           NaN       NaN  NaN
# 34967      34967  33823632  batch  33823632.batch  NaN  NaN   24786   comet   batch  NaN   NaN  mit178         NaN           NaN       NaN  NaN
# 35167      35167  33823812  batch  33823812.batch  NaN  NaN   15294   comet   batch  NaN   NaN  cla176         NaN           NaN       NaN  NaN
# 35169      35169  33823814  batch  33823814.batch  NaN  NaN   15294   comet   batch  NaN   NaN  cla176         NaN           NaN       NaN  NaN
# 35170      35170  33823815  batch  33823815.batch  NaN  NaN   15294   comet   batch  NaN   NaN  cla176         NaN           NaN       NaN  NaN
# 35185      35185  33823828  batch  33823828.batch  NaN  NaN   15294   comet   batch  NaN   NaN  cla176         NaN           NaN       NaN  NaN
# 35186      35186  33823829  batch  33823829.batch  NaN  NaN   15294   comet   batch  NaN   NaN  cla176         NaN           NaN       NaN  NaN
# 35187      35187  33823830  batch  33823830.batch  NaN  NaN   15294   comet   batch  NaN   NaN  cla176         NaN           NaN       NaN  NaN
# 35194      35194  33823835  batch  33823835.batch  NaN  NaN   15294   comet   batch  NaN   NaN  cla176         NaN           NaN       NaN  NaN
# 35195      35195  33823836  batch  33823836.batch  NaN  NaN   15294   comet   batch  NaN   NaN  cla176         NaN           NaN       NaN  NaN
# 35196      35196  33823837  batch  33823837.batch  NaN  NaN   15294   comet   batch  NaN   NaN  cla176         NaN           NaN       NaN  NaN
# 35204      35204  33823845  batch  33823845.batch  NaN  NaN   15294   comet   batch  NaN   NaN  cla176         NaN           NaN       NaN  NaN
#
#       QOSRAW NNODES NTASKS NCPUS AllocCPUS ReqCPUS ReqCPUFreq        ReqMem ReqGRES AllocGRES Timelimit Priority      State ExitCode  \
# 1908     NaN      1      1    24        24      24          0  9.538256e+11     NaN       NaN       NaN      NaN  COMPLETED      0:0
# 3021     NaN      1      1    24        24      24          0  9.538256e+11     NaN       NaN       NaN      NaN  COMPLETED      0:0
# 4196     NaN      1      1    24        24      24          0  9.538256e+11     NaN       NaN       NaN      NaN  COMPLETED      0:0
# 4197     NaN      1      1    12        12      12          0  1.144591e+13     NaN       NaN       NaN      NaN  COMPLETED      0:0
# 4198     NaN      1      1    12        12      12          0  1.144591e+13     NaN       NaN       NaN      NaN  COMPLETED      0:0
# 4199     NaN      1      1    12        12      12          0  1.144591e+13     NaN       NaN       NaN      NaN  COMPLETED      0:0
# 17683    NaN      1      1    24        24      24          0  9.538256e+11     NaN       NaN       NaN      NaN  COMPLETED      0:0
# 30174    NaN      1      1    12        12      12          0  1.144591e+13     NaN       NaN       NaN      NaN  CANCELLED     0:15
# 30175    NaN      1      1    12        12      12          0  1.144591e+13     NaN       NaN       NaN      NaN  CANCELLED     0:15
# 30177    NaN      1      1    12        12      12          0  1.144591e+13     NaN       NaN       NaN      NaN  CANCELLED     0:15
# 31037    NaN      1      1    24        24      24          0  2.235529e+10     NaN       NaN       NaN      NaN  CANCELLED     0:15
# 32876    NaN      1      1    12        12      12          0  1.144591e+13     NaN       NaN       NaN      NaN  COMPLETED      0:0
# 32877    NaN      1      1    12        12      12          0  1.144591e+13     NaN       NaN       NaN      NaN  CANCELLED     0:15
# 32878    NaN      1      1    12        12      12          0  1.144591e+13     NaN       NaN       NaN      NaN  CANCELLED     0:15
# 32879    NaN      1      1    12        12      12          0  1.144591e+13     NaN       NaN       NaN      NaN  CANCELLED     0:15
# 32880    NaN      1      1    12        12      12          0  1.144591e+13     NaN       NaN       NaN      NaN  CANCELLED     0:15
# 32881    NaN      1      1    12        12      12          0  1.144591e+13     NaN       NaN       NaN      NaN  CANCELLED     0:15
# 32882    NaN      1      1    12        12      12          0  1.144591e+13     NaN       NaN       NaN      NaN  CANCELLED     0:15
# 32883    NaN      1      1    12        12      12          0  1.144591e+13     NaN       NaN       NaN      NaN  CANCELLED     0:15
# 32884    NaN      1      1    12        12      12          0  1.144591e+13     NaN       NaN       NaN      NaN  CANCELLED     0:15
# 32887    NaN      1      1    12        12      12          0  1.144591e+13     NaN       NaN       NaN      NaN  CANCELLED     0:15
# 32888    NaN      1      1    12        12      12          0  1.144591e+13     NaN       NaN       NaN      NaN  CANCELLED     0:15
# 32889    NaN      1      1    12        12      12          0  1.144591e+13     NaN       NaN       NaN      NaN  CANCELLED     0:15
# 32890    NaN      1      1    12        12      12          0  1.144591e+13     NaN       NaN       NaN      NaN  CANCELLED     0:15
# 32891    NaN      1      1    12        12      12          0  1.144591e+13     NaN       NaN       NaN      NaN  CANCELLED     0:15
# 32892    NaN      1      1    12        12      12          0  1.144591e+13     NaN       NaN       NaN      NaN  CANCELLED     0:15
# 32893    NaN      1      1    12        12      12          0  1.144591e+13     NaN       NaN       NaN      NaN  CANCELLED     0:15
# 32894    NaN      1      1    12        12      12          0  1.144591e+13     NaN       NaN       NaN      NaN  CANCELLED     0:15
# 32895    NaN      1      1    12        12      12          0  1.144591e+13     NaN       NaN       NaN      NaN  COMPLETED      0:0
# 32904    NaN      1      1    12        12      12          0  1.144591e+13     NaN       NaN       NaN      NaN  COMPLETED      0:0
# 32905    NaN      1      1    12        12      12          0  1.144591e+13     NaN       NaN       NaN      NaN  COMPLETED      0:0
# 32906    NaN      1      1    12        12      12          0  1.144591e+13     NaN       NaN       NaN      NaN  CANCELLED     0:15
# 32907    NaN      1      1    12        12      12          0  1.144591e+13     NaN       NaN       NaN      NaN  CANCELLED     0:15
# 32908    NaN      1      1    12        12      12          0  1.144591e+13     NaN       NaN       NaN      NaN  CANCELLED     0:15
# 32909    NaN      1      1    12        12      12          0  1.144591e+13     NaN       NaN       NaN      NaN  CANCELLED     0:15
# 32910    NaN      1      1    12        12      12          0  1.144591e+13     NaN       NaN       NaN      NaN  CANCELLED     0:15
# 33071    NaN      1      1    12        12      12          0  1.144591e+13     NaN       NaN       NaN      NaN  COMPLETED      0:0
# 34553    NaN      1      1    12        12      12          0  1.144591e+13     NaN       NaN       NaN      NaN  COMPLETED      0:0
# 34882    NaN      1      1    12        12      12          0  1.144591e+13     NaN       NaN       NaN      NaN  COMPLETED      0:0
# 34967    NaN      1      1    24        24      24          0  2.235529e+10     NaN       NaN       NaN      NaN  CANCELLED     0:15
# 35167    NaN      1      1    12        12      12          0  1.144591e+13     NaN       NaN       NaN      NaN  CANCELLED     0:15
# 35169    NaN      1      1    12        12      12          0  1.144591e+13     NaN       NaN       NaN      NaN  CANCELLED     0:15
# 35170    NaN      1      1    12        12      12          0  1.144591e+13     NaN       NaN       NaN      NaN  CANCELLED     0:15
# 35185    NaN      1      1    12        12      12          0  1.144591e+13     NaN       NaN       NaN      NaN  CANCELLED     0:15
# 35186    NaN      1      1    12        12      12          0  1.144591e+13     NaN       NaN       NaN      NaN  CANCELLED     0:15
# 35187    NaN      1      1    12        12      12          0  1.144591e+13     NaN       NaN       NaN      NaN  CANCELLED     0:15
# 35194    NaN      1      1    12        12      12          0  1.144591e+13     NaN       NaN       NaN      NaN  CANCELLED     0:15
# 35195    NaN      1      1    12        12      12          0  1.144591e+13     NaN       NaN       NaN      NaN  CANCELLED     0:15
# 35196    NaN      1      1    12        12      12          0  1.144591e+13     NaN       NaN       NaN      NaN  CANCELLED     0:15
# 35204    NaN      1      1    12        12      12          0  1.144591e+13     NaN       NaN       NaN      NaN  CANCELLED     0:15
#
#       DerivedExitCode               Submit             Eligible                Start                  End Time     Elapsed Reserved Suspended  \
# 1908              NaN  2020-06-01T00:00:00  2020-06-01T00:00:00  2020-06-01T00:00:00  2020-06-02T02:16:43  NaN  1-02:16:43  INVALID  00:00:00
# 3021              NaN  2020-06-01T00:00:00  2020-06-01T00:00:00  2020-06-01T00:00:00  2020-06-01T23:44:00  NaN    23:44:00  INVALID  00:00:00
# 4196              NaN  2020-06-01T00:00:00  2020-06-01T00:00:00  2020-06-01T00:00:00  2020-06-02T09:33:13  NaN  1-09:33:13  INVALID  00:00:00
# 4197              NaN  2020-06-01T00:00:00  2020-06-01T00:00:00  2020-06-01T00:00:00  2020-06-01T04:46:00  NaN    04:46:00  INVALID  00:00:00
# 4198              NaN  2020-06-01T00:00:00  2020-06-01T00:00:00  2020-06-01T00:00:00  2020-06-01T06:17:42  NaN    06:17:42  INVALID  00:00:00
# 4199              NaN  2020-06-01T00:00:00  2020-06-01T00:00:00  2020-06-01T00:00:00  2020-06-01T06:52:30  NaN    06:52:30  INVALID  00:00:00
# 17683             NaN  2020-06-01T06:56:15  2020-06-01T06:56:15  2020-06-01T06:56:15  2020-06-01T09:43:07  NaN    02:46:52  INVALID  00:00:00
# 30174             NaN  2020-06-01T10:45:27  2020-06-01T10:45:27  2020-06-01T10:45:27  2020-06-01T13:16:49  NaN    02:31:22  INVALID  00:00:00
# 30175             NaN  2020-06-01T10:45:27  2020-06-01T10:45:27  2020-06-01T10:45:27  2020-06-01T13:16:49  NaN    02:31:22  INVALID  00:00:00
# 30177             NaN  2020-06-01T10:45:27  2020-06-01T10:45:27  2020-06-01T10:45:27  2020-06-01T13:16:49  NaN    02:31:22  INVALID  00:00:00
# 31037             NaN  2020-06-01T11:47:01  2020-06-01T11:47:01  2020-06-01T11:47:01  2020-06-01T13:12:53  NaN    01:25:52  INVALID  00:00:00
# 32876             NaN  2020-06-01T12:28:38  2020-06-01T12:28:38  2020-06-01T12:28:38  2020-06-01T12:56:09  NaN    00:27:31  INVALID  00:00:00
# 32877             NaN  2020-06-01T12:28:38  2020-06-01T12:28:38  2020-06-01T12:28:38  2020-06-01T13:19:07  NaN    00:50:29  INVALID  00:00:00
# 32878             NaN  2020-06-01T12:28:38  2020-06-01T12:28:38  2020-06-01T12:28:38  2020-06-01T13:19:07  NaN    00:50:29  INVALID  00:00:00
# 32879             NaN  2020-06-01T12:28:38  2020-06-01T12:28:38  2020-06-01T12:28:38  2020-06-01T13:19:08  NaN    00:50:30  INVALID  00:00:00
# 32880             NaN  2020-06-01T12:28:38  2020-06-01T12:28:38  2020-06-01T12:28:38  2020-06-01T13:19:08  NaN    00:50:30  INVALID  00:00:00
# 32881             NaN  2020-06-01T12:28:38  2020-06-01T12:28:38  2020-06-01T12:28:38  2020-06-01T13:19:08  NaN    00:50:30  INVALID  00:00:00
# 32882             NaN  2020-06-01T12:28:38  2020-06-01T12:28:38  2020-06-01T12:28:38  2020-06-01T13:19:08  NaN    00:50:30  INVALID  00:00:00
# 32883             NaN  2020-06-01T12:28:38  2020-06-01T12:28:38  2020-06-01T12:28:38  2020-06-01T13:19:08  NaN    00:50:30  INVALID  00:00:00
# 32884             NaN  2020-06-01T12:28:38  2020-06-01T12:28:38  2020-06-01T12:28:38  2020-06-01T13:19:08  NaN    00:50:30  INVALID  00:00:00
# 32887             NaN  2020-06-01T12:28:38  2020-06-01T12:28:38  2020-06-01T12:28:38  2020-06-01T13:19:33  NaN    00:50:55  INVALID  00:00:00
# 32888             NaN  2020-06-01T12:28:38  2020-06-01T12:28:38  2020-06-01T12:28:38  2020-06-01T13:19:33  NaN    00:50:55  INVALID  00:00:00
# 32889             NaN  2020-06-01T12:28:38  2020-06-01T12:28:38  2020-06-01T12:28:38  2020-06-01T13:19:33  NaN    00:50:55  INVALID  00:00:00
# 32890             NaN  2020-06-01T12:28:38  2020-06-01T12:28:38  2020-06-01T12:28:38  2020-06-01T13:19:34  NaN    00:50:56  INVALID  00:00:00
# 32891             NaN  2020-06-01T12:28:38  2020-06-01T12:28:38  2020-06-01T12:28:38  2020-06-01T13:19:34  NaN    00:50:56  INVALID  00:00:00
# 32892             NaN  2020-06-01T12:28:38  2020-06-01T12:28:38  2020-06-01T12:28:38  2020-06-01T13:19:34  NaN    00:50:56  INVALID  00:00:00
# 32893             NaN  2020-06-01T12:28:38  2020-06-01T12:28:38  2020-06-01T12:28:38  2020-06-01T13:19:34  NaN    00:50:56  INVALID  00:00:00
# 32894             NaN  2020-06-01T12:28:38  2020-06-01T12:28:38  2020-06-01T12:28:38  2020-06-01T13:19:34  NaN    00:50:56  INVALID  00:00:00
# 32895             NaN  2020-06-01T12:28:38  2020-06-01T12:28:38  2020-06-01T12:28:38  2020-06-01T12:55:35  NaN    00:26:57  INVALID  00:00:00
# 32904             NaN  2020-06-01T12:29:14  2020-06-01T12:29:14  2020-06-01T12:29:14  2020-06-01T12:55:15  NaN    00:26:01  INVALID  00:00:00
# 32905             NaN  2020-06-01T12:29:14  2020-06-01T12:29:14  2020-06-01T12:29:14  2020-06-01T12
# 17683               0.0  Unknown     NaN  comet-23-43  9.538101e+11
# 30174               0.0  Unknown     NaN  comet-06-39  1.144591e+13
# 30175               0.0  Unknown     NaN  comet-06-39  1.144591e+13
# 30177               0.0  Unknown     NaN  comet-05-24  1.144591e+13
# 31037               0.0  Unknown     NaN  comet-21-35  2.234934e+10
# 32876               0.0  Unknown     NaN  comet-01-02  1.144591e+13
# 32877               0.0  Unknown     NaN  comet-01-11  1.144591e+13
# 32878               0.0  Unknown     NaN  comet-02-23  1.144591e+13
# 32879               0.0  Unknown     NaN  comet-02-53  1.144591e+13
# 32880               0.0  Unknown     NaN  comet-03-08  1.144591e+13
# 32881               0.0  Unknown     NaN  comet-03-10  1.144591e+13
# 32882               0.0  Unknown     NaN  comet-03-40  1.144591e+13
# 32883               0.0  Unknown     NaN  comet-05-08  1.144591e+13
# 32884               0.0  Unknown     NaN  comet-05-24  1.144591e+13
# 32887               0.0  Unknown     NaN  comet-05-56  1.144591e+13
# 32888               0.0  Unknown     NaN  comet-06-58  1.144591e+13
# 32889               0.0  Unknown     NaN  comet-06-60  1.144591e+13
# 32890               0.0  Unknown     NaN  comet-06-63  1.144591e+13
# 32891               0.0  Unknown     NaN  comet-06-69  1.144591e+13
# 32892               0.0  Unknown     NaN  comet-06-70  1.144591e+13
# 32893               0.0  Unknown     NaN  comet-10-01  1.144591e+13
# 32894               0.0  Unknown     NaN  comet-10-08  1.144591e+13
# 32895               0.0  Unknown     NaN  comet-10-19  1.144591e+13
# 32904               0.0  Unknown     NaN  comet-10-46  1.144591e+13
# 32905               0.0  Unknown     NaN  comet-10-46  1.144591e+13
# 32906               0.0  Unknown     NaN  comet-05-38  1.144591e+13
# 32907               0.0  Unknown     NaN  comet-05-38  1.144591e+13
# 32908               0.0  Unknown     NaN  comet-05-71  1.144591e+13
# 32909               0.0  Unknown     NaN  comet-07-15  1.144591e+13
# 32910               0.0  Unknown     NaN  comet-07-21  1.144591e+13
# 33071               0.0  Unknown     NaN  comet-03-24  1.144591e+13
# 34553               0.0  Unknown     NaN  comet-01-15  1.144591e+13
# 34882               0.0  Unknown     NaN  comet-03-46  1.144591e+13
# 34967               0.0  Unknown     NaN  comet-06-39  2.234660e+10
# 35167               0.0  Unknown     NaN  comet-06-10  1.144591e+13
# 35169               0.0  Unknown     NaN  comet-06-19  1.144591e+13
# 35170               0.0  Unknown     NaN  comet-06-40  1.144591e+13
# 35185               0.0  Unknown     NaN  comet-02-57  1.144591e+13
# 35186               0.0  Unknown     NaN  comet-06-26  1.144591e+13
# 35187               0.0  Unknown     NaN  comet-02-72  1.144591e+13
# 35194               0.0  Unknown     NaN  comet-06-53  1.144591e+13
# 35195               0.0  Unknown     NaN  comet-06-58  1.144591e+13
# 35196               0.0  Unknown     NaN  comet-06-60  1.144591e+13
# 35204               0.0  Unknown     NaN  comet-06-63  1.144591e+13

# %%
queryDF.compute().describe()

# %%
# Query save system: If desired, users can save their current query as a parquet file for use later

saveName = 'sacctQuery'  # Doesn't need to include the .parqet or .csv extension
queryDF.to_parquet(saveName+'.parquet')
